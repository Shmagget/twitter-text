# %% [markdown]
# **For this assignment Im going to see which playlists i listen to when im in different moods by looking at the features of different songs on the playlist.**

# %% [markdown]
# first im going to import the packages that i need to start this assignment

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from scipy import stats
import json5 as js
import base64
import requests

# %% [markdown]
# then im calling on my keys and bearer tokens to gain access to the spotify API

# %%
keys = pd.read_csv('spotify.txt', sep = ",", header = 0)
appid = keys['Client_ID'][0]
appsecret = keys['Client_Secret'][0]
client_cred = base64.b64encode(str(appid+":"+ appsecret).encode('ascii'))
header = {'Authorization': 'Basic {}'.format(client_cred.decode('ascii'))}
payload = {'grant_type' : 'client_credentials'}
access_token_url = "https://accounts.spotify.com/api/token"
response = requests.post(access_token_url, headers = header,data = payload)
session_token = response.json()['access_token']
session_header = {'Authorization' : 'Bearer {}'.format(response.json()['access_token'])}

# %% [markdown]
# Now im grabbing the playlist IDs along with requesting the link to the spotify API, This data is coming from the from the spotify api and the links connected to each playlist that people create.

# %%
Playlist_1 = '439oBnNyLGO8S8ZZR139lh'
Playlist_2 = '6aFQL95GlX8VfCmVAij8uD'
Playlist_3 = '2mgo5Gj5goJhyn9tVKjKSs'
P1_endpoint = "https://api.spotify.com/v1/playlists/{}/tracks".format(Playlist_1)
P2_endpoint = "https://api.spotify.com/v1/playlists/{}/tracks".format(Playlist_2)
P3_endpoint = "https://api.spotify.com/v1/playlists/{}/tracks".format(Playlist_3)
P1_tracks = requests.get(P1_endpoint, headers = session_header)
P2_tracks = requests.get(P2_endpoint, headers = session_header)
P3_tracks = requests.get(P3_endpoint, headers = session_header)

# %% [markdown]
# This is loading the tracks and ids for them so when i call in a dataframe it shows the id

# %%
P1_dict = js.loads(P1_tracks.text)
P1_track_ids = [x['track']['id'] for x in P1_dict['items']]
P2_dict = js.loads(P2_tracks.text)
P2_track_ids = [x['track']['id'] for x in P2_dict['items']]
P3_dict = js.loads(P3_tracks.text)
P3_track_ids = [x['track']['id'] for x in P3_dict['items']]

# %% [markdown]
# Gathering the endpoints for the features i can look at with each individual song on my playlists

# %%
P1_features_endpoint = "https://api.spotify.com/v1/audio-features?ids={}".format(','.join(str(x) for x in P1_track_ids))
P1_features = requests.get(P1_features_endpoint, headers = session_header)
P2_features_endpoint = "https://api.spotify.com/v1/audio-features?ids={}".format(','.join(str(x) for x in P2_track_ids))
P2_features = requests.get(P2_features_endpoint, headers = session_header)
P3_features_endpoint = "https://api.spotify.com/v1/audio-features?ids={}".format(','.join(str(x) for x in P3_track_ids))
P3_features = requests.get(P3_features_endpoint, headers = session_header)

# %% [markdown]
# loading the features onto a text file on the dataframe so you can see what song has what feature. also creating the dataframe for each of the playlists

# %%
P1_dict = js.loads(P1_features.text)
P2_dict = js.loads(P2_features.text)
P3_dict = js.loads(P3_features.text)
P1_df = pd.DataFrame(P1_dict['audio_features'])
P2_df = pd.DataFrame(P2_dict['audio_features'])
P3_df = pd.DataFrame(P3_dict['audio_features'])
P1_df['Playlist'] = ['Playlist_1'] * len(P1_df.index)
P3_df['Playlist'] = ['Playlist_3'] * len(P3_df.index)

# %% [markdown]
# Playlist number 1, this along with the other playlists are dataframes  defined by different features that each song is rated with on spotify

# %%
P1_df
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.655   0.885    7    -4.116     1       0.0438      0.001170
# 1          0.678   0.656    7    -6.410     1       0.0381      0.001740
# 2          0.350   0.828    6    -5.373     1       0.0410      0.000217
# 3          0.577   0.828    6    -8.691     0       0.0298      0.002130
# 4          0.556   0.864    3    -5.870     0       0.0584      0.009580
# ..           ...     ...  ...       ...   ...          ...           ...
# 89         0.654   0.611    2   -10.450     1       0.1190      0.033700
# 90         0.382   0.867    9    -7.426     1       0.0399      0.000006
# 91         0.451   0.962    0    -3.947     1       0.0734      0.018800
# 92         0.394   0.944   10    -6.506     0       0.0761      0.001780
# 93         0.398   0.927    9    -4.212     1       0.0567      0.000062
#
#     instrumentalness  liveness  valence    tempo            type  \
# 0           0.000473    0.0448    0.938  100.088  audio_features
# 1           0.000000    0.0631    0.485  123.207  audio_features
# 2           0.000161    0.0774    0.147  105.435  audio_features
# 3           0.011400    0.0581    0.604  123.257  audio_features
# 4           0.000000    0.2090    0.400  105.143  audio_features
# ..               ...       ...      ...      ...             ...
# 89          0.000178    0.4050    0.786   85.387  audio_features
# 90          0.581000    0.1960    0.453   87.309  audio_features
# 91          0.000003    0.2770    0.377  131.435  audio_features
# 92          0.000005    0.2980    0.265  105.338  audio_features
# 93          0.000177    0.0575    0.311   77.106  audio_features
#
#                         id                                   uri  \
# 0   1fLlRApgzxWweF1JTf8yM5  spotify:track:1fLlRApgzxWweF1JTf8yM5
# 1   26D1PRJjD9Jj1JGRk88KVc  spotify:track:26D1PRJjD9Jj1JGRk88KVc
# 2   2EoOZnxNgtmZaD8uUmz2nD  spotify:track:2EoOZnxNgtmZaD8uUmz2nD
# 3   5sICkBXVmaCQk5aISGR3x1  spotify:track:5sICkBXVmaCQk5aISGR3x1
# 4   60a0Rd6pjrkxjPbaKzXjfq  spotify:track:60a0Rd6pjrkxjPbaKzXjfq
# ..                     ...                                   ...
# 89  5PntSbMHC1ud6Vvl8x56qd  spotify:track:5PntSbMHC1ud6Vvl8x56qd
# 90  3ow0TQVttXQF8rLckmXgRx  spotify:track:3ow0TQVttXQF8rLckmXgRx
# 91  4ECNtOnqzxutZkXP4TE3n3  spotify:track:4ECNtOnqzxutZkXP4TE3n3
# 92  6QewNVIDKdSl8Y3ycuHIei  spotify:track:6QewNVIDKdSl8Y3ycuHIei
# 93  4dVbhS6OiYvFikshyaQaCN  spotify:track:4dVbhS6OiYvFikshyaQaCN
#
#                                            track_href  \
# 0   https://api.spotify.com/v1/tracks/1fLlRApgzxWw...
# 1   https://api.spotify.com/v1/tracks/26D1PRJjD9Jj...
# 2   https://api.spotify.com/v1/tracks/2EoOZnxNgtmZ...
# 3   https://api.spotify.com/v1/tracks/5sICkBXVmaCQ...
# 4   https://api.spotify.com/v1/tracks/60a0Rd6pjrkx...
# ..                                                ...
# 89  https://api.spotify.com/v1/tracks/5PntSbMHC1ud...
# 90  https://api.spotify.com/v1/tracks/3ow0TQVttXQF...
# 91  https://api.spotify.com/v1/tracks/4ECNtOnqzxut...
# 92  https://api.spotify.com/v1/tracks/6QewNVIDKdSl...
# 93  https://api.spotify.com/v1/tracks/4dVbhS6OiYvF...
#
#                                          analysis_url  duration_ms  \
# 0   https://api.spotify.com/v1/audio-analysis/1fLl...       189293
# 1   https://api.spotify.com/v1/audio-analysis/26D1...       257053
# 2   https://api.spotify.com/v1/audio-analysis/2EoO...       318587
# 3   https://api.spotify.com/v1/audio-analysis/5sIC...       331267
# 4   https://api.spotify.com/v1/audio-analysis/60a0...       216880
# ..                                                ...          ...
# 89  https://api.spotify.com/v1/audio-analysis/5Pnt...       235000
# 90  https://api.spotify.com/v1/audio-analysis/3ow0...       298253
# 91  https://api.spotify.com/v1/audio-analysis/4ECN...       323707
# 92  https://api.spotify.com/v1/audio-analysis/6Qew...       292581
# 93  https://api.spotify.com/v1/audio-analysis/4dVb...       260027
#
#     time_signature    Playlist
# 0                4  Playlist_1
# 1                4  Playlist_1
# 2                4  Playlist_1
# 3                4  Playlist_1
# 4                4  Playlist_1
# ..             ...         ...
# 89               4  Playlist_1
# 90               4  Playlist_1
# 91               4  Playlist_1
# 92               4  Playlist_1
# 93               4  Playlist_1
#
# [94 rows x 19 columns]

# %% [markdown]
# Playlist number 2

# %%
P2_df
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.319   0.236    5    -9.644     1       0.0318        0.8980
# 1          0.676   0.536    2    -8.790     1       0.0432        0.4030
# 2          0.583   0.625    1    -8.011     1       0.2770        0.5060
# 3          0.726   0.478    1    -6.605     0       0.1070        0.6450
# 4          0.485   0.720    6    -5.991     1       0.1270        0.0123
# ..           ...     ...  ...       ...   ...          ...           ...
# 95         0.856   0.841    6    -7.737     0       0.3350        0.0977
# 96         0.489   0.624    4    -1.916     0       0.0344        0.8340
# 97         0.695   0.827    6    -5.742     0       0.2820        0.1790
# 98         0.509   0.787    7    -6.754     1       0.2650        0.3590
# 99         0.629   0.676    1    -7.088     0       0.1910        0.5300
#
#     instrumentalness  liveness  valence    tempo            type  \
# 0           0.000016    0.2720   0.2540  162.351  audio_features
# 1           0.000034    0.1050   0.3730   79.037  audio_features
# 2           0.000000    0.1960   0.5160   89.812  audio_features
# 3           0.000003    0.1510   0.3380   74.992  audio_features
# 4           0.000000    0.0546   0.0471  207.982  audio_features
# ..               ...       ...      ...      ...             ...
# 95          0.000000    0.0773   0.7940   95.418  audio_features
# 96          0.347000    0.3250   0.5740  167.108  audio_features
# 97          0.000000    0.2830   0.5380   81.024  audio_features
# 98          0.000028    0.2600   0.5070  114.449  audio_features
# 99          0.000325    0.7010   0.4970   90.377  audio_features
#
#                         id                                   uri  \
# 0   7CC6UbCs4iGsePSzFxYxNn  spotify:track:7CC6UbCs4iGsePSzFxYxNn
# 1   58k32my5lKofeZRtIvBDg9  spotify:track:58k32my5lKofeZRtIvBDg9
# 2   0GAyuCo975IHGxxiLKDufB  spotify:track:0GAyuCo975IHGxxiLKDufB
# 3   1IMgQoUuiOuieYRKYadkPr  spotify:track:1IMgQoUuiOuieYRKYadkPr
# 4   1j6kDJttn6wbVyMaM42Nxm  spotify:track:1j6kDJttn6wbVyMaM42Nxm
# ..                     ...                                   ...
# 95  7lT1dCz96jANsLAAADlfIg  spotify:track:7lT1dCz96jANsLAAADlfIg
# 96  6cmt9CRoK0KGcNg9Tpje53  spotify:track:6cmt9CRoK0KGcNg9Tpje53
# 97  4WEuEfFiczWxblHyuucSBL  spotify:track:4WEuEfFiczWxblHyuucSBL
# 98  7Ks4VCY1wFebnOdJrM13t6  spotify:track:7Ks4VCY1wFebnOdJrM13t6
# 99  7umZiitjVsEjMQ6HNddpUI  spotify:track:7umZiitjVsEjMQ6HNddpUI
#
#                                            track_href  \
# 0   https://api.spotify.com/v1/tracks/7CC6UbCs4iGs...
# 1   https://api.spotify.com/v1/tracks/58k32my5lKof...
# 2   https://api.spotify.com/v1/tracks/0GAyuCo975IH...
# 3   https://api.spotify.com/v1/tracks/1IMgQoUuiOui...
# 4   https://api.spotify.com/v1/tracks/1j6kDJttn6wb...
# ..                                                ...
# 95  https://api.spotify.com/v1/tracks/7lT1dCz96jAN...
# 96  https://api.spotify.com/v1/tracks/6cmt9CRoK0KG...
# 97  https://api.spotify.com/v1/tracks/4WEuEfFiczWx...
# 98  https://api.spotify.com/v1/tracks/7Ks4VCY1wFeb...
# 99  https://api.spotify.com/v1/tracks/7umZiitjVsEj...
#
#                                          analysis_url  duration_ms  \
# 0   https://api.spotify.com/v1/audio-analysis

#
#     instrumentalness  liveness  valence    tempo            type  \
# 0           0.534000    0.1020   0.5440  165.990  audio_features
# 1           0.005450    0.0960   0.5720  104.970  audio_features
# 2           0.912000    0.2880   0.2250   87.692  audio_features
# 3           0.000003    0.1090   0.4170  138.015  audio_features
# 4           0.100000    0.1140   0.0772  126.628  audio_features
# 5           0.000308    0.0805   0.3640  158.066  audio_features
# 6           0.010700    0.1070   0.0641  110.007  audio_features
# 7           0.004250    0.1050   0.2750  193.947  audio_features
# 8           0.000000    0.0831   0.2730  113.980  audio_features
# 9           0.012600    0.1330   0.0906  107.025  audio_features
# 10          0.312000    0.0837   0.1710  127.163  audio_features
# 11          0.030100    0.1090   0.1830   74.995  audio_features
# 12          0.728000    0.1430   0.2530  128.153  audio_features
# 13          0.896000    0.0832   0.1810  116.334  audio_features
# 14          0.847000    0.1280   0.4340  167.608  audio_features
# 15          0.000046    0.0936   0.7060   93.206  audio_features
# 16          0.001200    0.1460   0.4710   78.848  audio_features
# 17          0.833000    0.2160   0.4300  139.980  audio_features
# 18          0.000013    0.0986   0.1760   93.568  audio_features
# 19          0.899000    0.0860   0.8660  122.072  audio_features
# 20          0.191000    0.1510   0.4690   78.477  audio_features
# 21          0.520000    0.0939   0.5020  141.013  audio_features
# 22          0.970000    0.1020   0.6520   79.223  audio_features
# 23          0.281000    0.3460   0.2270   80.973  audio_features
# 24          0.000188    0.1380   0.4970  124.023  audio_features
# 25          0.398000    0.1990   0.5230   77.494  audio_features
# 26          0.000838    0.0878   0.2430   81.201  audio_features
# 27          0.000000    0.1700   0.5940  113.551  audio_features
# 28          0.365000    0.3740   0.3660  132.542  audio_features
# 29          0.095600    0.2060   0.6140  138.827  audio_features
# 30          0.000227    0.3490   0.5630  104.965  audio_features
# 31          0.583000    0.0513   0.9640  126.879  audio_features
# 32          0.690000    0.0490   0.4080   82.955  audio_features
# 33          0.006910    0.1420   0.1700  124.010  audio_features
# 34          0.452000    0.1070   0.4020  105.958  audio_features
# 35          0.003610    0.1130   0.1180   76.426  audio_features
# 36          0.002570    0.0679   0.5790   80.184  audio_features
# 37          0.867000    0.1270   0.2720  170.073  audio_features
# 38          0.827000    0.3670   0.1680   92.615  audio_features
# 39          0.006980    0.1110   0.2970  139.081  audio_features
# 40          0.075900    0.1160   0.0964   89.981  audio_features
# 41          0.060600    0.0910   0.0456   77.562  audio_features
# 42          0.000649    0.3230   0.2360  114.963  audio_features
# 43          0.000004    0.1280   0.6380  176.153  audio_features
#
#                         id                                   uri  \
# 0   01TyFEZu6mHbffsVfxgrFn  spotify:track:01TyFEZu6mHbffsVfxgrFn
# 1   6dBUzqjtbnIa1TwYbyw5CM  spotify:track:6dBUzqjtbnIa1TwYbyw5CM
# 2   72cGBEqu7RitIOoACXYjfR  spotify:track:72cGBEqu7RitIOoACXYjfR
# 3   1mea3bSkSGXuIRvnydlB5b  spotify:track:1mea3bSkSGXuIRvnydlB5b
# 34  https://api.spotify.com/v1/audio-analysis/5T0I...       197733
# 35  https://api.spotify.com/v1/audio-analysis/10ny...       229120
# 36  https://api.spotify.com/v1/audio-analysis/5Wht...       305533
# 37  https://api.spotify.com/v1/audio-analysis/2Xwc...       157973
# 38  https://api.spotify.com/v1/audio-analysis/4Uiw...       299867
# 39  https://api.spotify.com/v1/audio-analysis/2QzK...       143080
# 40  https://api.spotify.com/v1/audio-analysis/1Ery...       241533
# 41  https://api.spotify.com/v1/audio-analysis/4cLd...       225293
# 42  https://api.spotify.com/v1/audio-analysis/6kOH...       304427
# 43  https://api.spotify.com/v1/audio-analysis/2uuJ...       220387
#
#     time_signature    Playlist
# 0                4  Playlist_3
# 1                4  Playlist_3
# 2                4  Playlist_3
# 3                4  Playlist_3
# 4                4  Playlist_3
# 5                4  Playlist_3
# 6                4  Playlist_3
# 7                4  Playlist_3
# 8                4  Playlist_3
# 9                4  Playlist_3
# 10               4  Playlist_3
# 11               4  Playlist_3
# 12               4  Playlist_3
# 13               4  Playlist_3
# 14               4  Playlist_3
# 15               4  Playlist_3
# 16               4  Playlist_3
# 17               4  Playlist_3
# 18               4  Playlist_3
# 19               4  Playlist_3
# 20               4  Playlist_3
# 21               4  Playlist_3
# 22               4  Playlist_3
# 23               4  Playlist_3
# 24               4  Playlist_3
# 25               4  Playlist_3
# 26               4  Playlist_3
# 27               4  Playlist_3
# 28               4  Playlist_3
# 29               4  Playlist_3
# 30               4  Playlist_3
# 31               4  Playlist_3
# 32               4  Playlist_3
# 33               4  Playlist_3
# 34               4  Playlist_3
# 35               4  Playlist_3
# 36               4  Playlist_3
# 37               4  Playlist_3
# 38               4  Playlist_3
# 39               4  Playlist_3
# 40               4  Playlist_3
# 41               4  Playlist_3
# 42               4  Playlist_3
# 43               4  Playlist_3

# %% [markdown]
# **Now i need to start my analysis plan**                                        .

# %% [markdown]
# im going to select the features that can play a big role in figuring out why i listen to a certain playlist

# %% [markdown]
# Before i continue more i would like to state that playlist 1 is a rock based album, playlist 2 is a hip hop based album and playlist 3 is a calmer indie album

# %%
fig1, ax1 = plt.subplots(7,3, layout = 'constrained', figsize = (40,40))
ax1[0,0].set_title("energy", size = 40)
ax1[0,1].set_title("energy",size = 40)
ax1[0,2].set_title("energy",size = 40)
ax1[0,0].hist(P1_df['energy'], color  = 'green',alpha = 0.5)
ax1[0,1].hist(P2_df['energy'], color  = 'blue',alpha = 0.5)
ax1[0,2].hist(P3_df['energy'], color  = 'red',alpha = 0.5)

ax1[1,0].set_title("danceability", size = 40)
ax1[1,1].set_title("danceability",size = 40)
ax1[1,2].set_title("danceability",size = 40)
ax1[1,0].hist(P1_df['danceability'], color  = 'green',alpha = 0.5)
ax1[1,1].hist(P2_df['danceability'], color  = 'blue',alpha = 0.5)
ax1[1,2].hist(P3_df['danceability'], color  = 'red',alpha = 0.5)

ax1[2,0].set_title("loudness", size = 40)
ax1[2,1].set_title("loudness",size = 40)
ax1[2,2].set_title("loudness",size = 40)
ax1[2,0].hist(P1_df['loudness'], color  = 'green',alpha = 0.5)
ax1[2,1].hist(P2_df['loudness'], color  = 'blue',alpha = 0.5)
ax1[2,2].hist(P3_df['loudness'], color  = 'red',alpha = 0.5)

ax1[3,0].set_title("acousticness",size = 40)
ax1[3,1].set_title("acousticness",size = 40)
ax1[3,2].set_title("acousticness",size = 40)
ax1[3,0].hist(P1_df['acousticness'], color  = 'green',alpha = 0.5)
ax1[3,1].hist(P2_df['acousticness'], color  = 'blue',alpha = 0.5)
ax1[3,2].hist(P3_df['acousticness'], color  = 'red',alpha = 0.5)

ax1[4,0].set_title("tempo",size = 40)
ax1[4,1].set_title("tempo",size = 40)
ax1[4,2].set_title("tempo",size = 40)
ax1[4,0].hist(P1_df['tempo'], color  = 'green',alpha = 0.5)
ax1[4,1].hist(P2_df['tempo'], color  = 'blue',alpha = 0.5)
ax1[4,2].hist(P3_df['tempo'], color  = 'red',alpha = 0.5)

ax1[5,0].set_title("valence",size = 40)
ax1[5,1].set_title("valence",size = 40)
ax1[5,2].set_title("valence",size = 40)
ax1[5,0].hist(P1_df['valence'], color  = 'green',alpha = 0.5)
ax1[5,1].hist(P2_df['valence'], color  = 'blue',alpha = 0.5)
ax1[5,2].hist(P3_df['valence'], color  = 'red',alpha = 0.5)

ax1[6,0].set_title("instrumentalness",size = 40)
ax1[6,1].set_title("instrumentalness",size = 40)
ax1[6,2].set_title("instrumentalness",size = 40)
ax1[6,0].hist(P1_df['instrumentalness'], color  = 'green',alpha = 0.5)
ax1[6,1].hist(P2_df['instrumentalness'], color  = 'blue',alpha = 0.5)
ax1[6,2].hist(P3_df['instrumentalness'], color  = 'red',alpha = 0.5)
plt.show()

# %% [markdown]
# Im seeing alot of similarities suprisingly between the playlists despite them being from completely different genres\
# To better show how different they are im going to compare each of these in a singular plot for each feature instead of seperating them

# %%
fig1, ax1 = plt.subplots(7,1, layout = 'constrained', figsize = (20,40))
ax1[0].set_title("energy", size = 40)
ax1[0].hist(P1_df['energy'], color  = 'green',alpha = 0.5)
ax1[0].hist(P2_df['energy'], color  = 'blue',alpha = 0.5)
ax1[0].hist(P3_df['energy'], color  = 'red',alpha = 0.5)

ax1[1].set_title("danceability", size = 40)
ax1[1].hist(P1_df['danceability'], color  = 'green',alpha = 0.5)
ax1[1].hist(P2_df['danceability'], color  = 'blue',alpha = 0.5)
ax1[1].hist(P3_df['danceability'], color  = 'red',alpha = 0.5)

ax1[2].set_title("loudness", size = 40)
ax1[2].hist(P1_df['loudness'], color  = 'green',alpha = 0.5)
ax1[2].hist(P2_df['loudness'], color  = 'blue',alpha = 0.5)
ax1[2].hist(P3_df['loudness'], color  = 'red',alpha = 0.5)

ax1[3].set_title("acousticness",size = 40)
ax1[3].hist(P1_df['acousticness'], color  = 'green',alpha = 0.5)
ax1[3].hist(P2_df['acousticness'], color  = 'blue',alpha = 0.5)
ax1[3].hist(P3_df['acousticness'], color  = 'red',alpha = 0.5)

ax1[4].set_title("tempo",size = 40)
ax1[4].hist(P1_df['tempo'], color  = 'green',alpha = 0.5)
ax1[4].hist(P2_df['tempo'], color  = 'blue',alpha = 0.5)
ax1[4].hist(P3_df['tempo'], color  = 'red',alpha = 0.5)

ax1[5].set_title("valence",size = 40)
ax1[5].hist(P1_df['valence'], color  = 'green',alpha = 0.5)
ax1[5].hist(P2_df['valence'], color  = 'blue',alpha = 0.5)
ax1[5].hist(P3_df['valence'], color  = 'red',alpha = 0.5)

ax1[6].set_title("instrumentalness",size = 40)
ax1[6].hist(P1_df['instrumentalness'], color  = 'green',alpha = 0.5)
ax1[6].hist(P2_df['instrumentalness'], color  = 'blue',alpha = 0.5)
ax1[6].hist(P3_df['instrumentalness'], color  = 'red',alpha = 0.5)
plt.show()

# %% [markdown]
# seeing this makes it more clear, the rock album has more energy between all tracks with over 30 at max energy with just a few outliers sitting in places right next to it while hiphop stands near the middle, and as expected, the calmer indie is pretty much non existant on the energy scale with it peaking at 0.4
#
# Danceability and instrumenalness are both very similar across each playlist. mostly all the songs on each of these playlists sit with each other in those categories.
#
# seeing all of these compiled i have decided to leave out instrumentalness because it doesnt really show that great of data. In the near future I will take the other six and pair them up and use a scatter plot to show if one feature effect the other.
#
# I will pair valence and acousticness, Loudness and Energy and Danceability and Tempo

# %%
fig1, ax1 = plt.subplots(1,3, layout = 'constrained', figsize = (20, 5))
ax1[0].scatter(P1_df['energy'], P1_df['loudness'], alpha = 0.5, color = 'green')
ax1[0].set_xlabel ('Energy')
ax1[0].set_ylabel('Loudness')

ax1[1].scatter(P2_df['energy'], P2_df['loudness'], alpha = 0.5, color = 'blue')
ax1[1].set_xlabel ('Energy')
ax1[1].set_ylabel('Loudness')

ax1[2].scatter(P3_df['energy'], P3_df['loudness'], alpha = 0.5, color = 'red')
ax1[2].set_xlabel ('Energy')
ax1[2].set_ylabel('loudness')


plt.show()

# %%
fig1, ax1 = plt.subplots(1,3, layout = 'constrained', figsize = (20, 5))
ax1[0].scatter(P1_df['danceability'], P1_df['tempo'], alpha = 0.5, color = 'green')
ax1[0].set_xlabel ('Danceability')
ax1[0].set_ylabel('{Tempo}')

ax1[1].scatter(P2_df['danceability'], P2_df['tempo'], alpha = 0.5, color = 'blue')
ax1[1].set_xlabel ('Danceability')
ax1[1].set_ylabel('Tempo')

ax1[2].scatter(P3_df['danceability'], P3_df['tempo'], alpha = 0.5, color = 'red')
ax1[2].set_xlabel ('Danceability')
ax1[2].set_ylabel('Tempo')


plt.show()

# %%
fig1, ax1 = plt.subplots(1,3, layout = 'constrained', figsize = (20, 5))
ax1[0].scatter(P1_df['valence'], P1_df['acousticness'], alpha = 0.5, color = 'green')
ax1[0].set_xlabel ('Valence')
ax1[0].set_ylabel('Acousticness')

ax1[1].scatter(P2_df['valence'], P2_df['acousticness'], alpha = 0.5, color = 'blue')
ax1[1].set_xlabel ('Valence')
ax1[1].set_ylabel('Acousticness')

ax1[2].scatter(P3_df['valence'], P3_df['acousticness'], alpha = 0.5, color = 'red')
ax1[2].set_xlabel ('Valence')
ax1[2].set_ylabel('Acousticness')


plt.show()

# %% [markdown]
# Seeing all this shows me what i was searching to find. Shows me what different playlists have in order for me to listen to them. If i want a loud and energetic album that gets me amped ill listen to Playlist 1. If i want something to dance to something ill listen to Playlist 2 and if i wanted something with alot of acousticness ill listen to Playlist 3.
# Also seeing how well the features pair with each other alot of these scatter plots have positive relations between graphs
